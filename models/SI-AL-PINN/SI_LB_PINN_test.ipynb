# %% [markdown]
# # SI-LB-PINN example
# This notebook imports and runs the standalone script `si_lb_pinn.py` created alongside this notebook.

# %%
import os
print('Listing files in current directory:')
print(os.listdir('/mnt/data'))
print('\nRunning the training script (this may take a while)...')
os.system('python3 /mnt/data/si_lb_pinn.py')
